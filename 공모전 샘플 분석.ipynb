# %%
import pandas as pd
import numpy as np
import plotly.express as px

pd.set_option('display.max_rows', 100)

# %%
kb = pd.read_excel('KB국민_지역별세부음식.xlsx')
bc = pd.read_excel('BC카드_온라인.xlsx')
seoul = pd.read_excel('신한_서울시지역.xlsx')
city = pd.read_excel('신한카드_광역시별.xlsx')

# %% [markdown]
# ## KB 데이터 - 요식업 관련

# %%
kb.describe()
# Out:
#          기준년도    기준월      신용카드보유      체크카드보유         회원수        매출건수  \
# count   100.0  100.0  100.000000  100.000000  100.000000   100.00000
# mean   2019.0    3.0    0.730000    0.540000   59.300000    77.14000
# std       0.0    0.0    0.446196    0.500908  104.438615   150.80518
# min    2019.0    3.0    0.000000    0.000000    5.000000     5.00000
# 25%    2019.0    3.0    0.000000    0.000000   11.000000    12.75000
# 50%    2019.0    3.0    1.000000    1.000000   26.500000    32.50000
# 75%    2019.0    3.0    1.000000    1.000000   60.000000    76.00000
# max    2019.0    3.0    1.000000    1.000000  745.000000  1176.00000
#
#              가맹점수          순위
# count  100.000000  100.000000
# mean    12.360000   15.740000
# std     23.694401   12.326878
# min      1.000000    1.000000
# 25%      3.000000    4.750000
# 50%      5.000000   14.000000
# 75%     11.000000   23.750000
# max    161.000000   46.000000

# %%
kb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   기준년도        100 non-null    int64
#  1   기준월         100 non-null    int64
#  2   한글시도명       100 non-null    object
#  3   한글시군구명      100 non-null    object
#  4   법정동리명       100 non-null    object
#  5   마케팅업종중분류명   100 non-null    object
#  6   마케팅업종세분류명   100 non-null    object
#  7   마케팅업종세세분류명  100 non-null    object
#  8   성별구분        100 non-null    object
#  9   연령대         100 non-null    object
#  10  신용카드보유      100 non-null    int64
#  11  체크카드보유      100 non-null    int64
#  12  회원수         100 non-null    int64
#  13  매출건수        100 non-null    int64
#  14  가맹점수        100 non-null    int64
#  15  순위          100 non-null    int64
# dtypes: int64(8), object(8)
# memory usage: 12.6+ KB

# %%
kb.head(3)
# Out:
#    기준년도  기준월  한글시도명   한글시군구명 법정동리명 마케팅업종중분류명 마케팅업종세분류명 마케팅업종세세분류명   성별구분  \
# 0  2019    3    경기도  성남시 분당구   정자동        한식   국/탕/백반류  김치찜/찌개전문점  01.남성
# 1  2019    3    경기도  성남시 분당구   수내동        일식       밥요리  덮밥/가정식전문점  02.여성
# 2  2019    3  서울특별시      강남구   논현동        한식   국/탕/백반류    부대찌개전문점  02.여성
#
#      연령대  신용카드보유  체크카드보유  회원수  매출건수  가맹점수  순위
# 0  3.40대       1       1   26    31     2  46
# 1  3.40대       1       0   29    36     2  45
# 2  3.40대       1       1   78    85    13  42

# %%
''' - KB국민
    기준년도
    기준월
    한글시도명 : 서울특별시
    한글시군구명 : 강남구
    법정동리명 : 논현동
    마케팅업종증분류명 : 한식
    마케팅업종세분류명 : 김치찜/찌개
    성별구분 : 01.남성
    연령대 : 3.40대
    신용카드보유 : 1
    체크카드보유 : 1
    회원수 : 26
    매출건수 : 31
    가맹점수 : 2
    순위 : 45
'''
# Out:
# ' - KB국민\n    기준년도\n    기준월\n    한글시도명 : 서울특별시\n    한글시군구명 : 강남구\n    법정동리명 : 논현동\n    마케팅업종증분류명 : 한식\n    마케팅업종세분류명 : 김치찜/찌개\n    성별구분 : 01.남성\n    연령대 : 3.40대\n    신용카드보유 : 1\n    체크카드보유 : 1\n    회원수 : 26\n    매출건수 : 31\n    가맹점수 : 2\n    순위 : 45\n'

# %%
kb.sort_values(by='순위')
# Out:
#     기준년도  기준월  한글시도명   한글시군구명 법정동리명 마케팅업종중분류명 마케팅업종세분류명 마케팅업종세세분류명   성별구분  \
# 99  2019    3  서울특별시      마포구  신공덕동        한식   국/탕/백반류    일반한식/백반  02.여성
# 85  2019    3  서울특별시      강남구   수서동        한식   국/탕/백반류    일반한식/백반  01.남성
# 86  2019    3  서울특별시      마포구   대흥동        한식   국/탕/백반류    일반한식/백반  02.여성
# 87  2019    3  서울특별시      마포구   성산동        한식   국/탕/백반류    일반한식/백반  01.남성
# 88  2019    3  서울특별시      강남구   수서동        한식   국/탕/백반류    일반한식/백반  02.여성
# 89  2019    3  서울특별시      마포구   대흥동        한식   국/탕/백반류    일반한식/백반  02.여성
# 90  2019    3  서울특별시      마포구   염리동        한식   국/탕/백반류    일반한식/백반  02.여성
# 98  2019    3  서울특별시      강남구   대치동        한식   국/탕/백반류    일반한식/백반  02.여성
# 92  2019    3    경기도  성남시 분당구   삼평동        한식   국/탕/백반류    일반한식/백반  02.여성
# 97  2019    3    경기도  성남시 분당구   수내동        한식   국/탕/백반류    일반한식/백반  01.남성
# 96  2019    3  서울특별시      마포구   마포동        한식   국/탕/백반류    일반한식/백반  01.남성
# 91  2019    3  서울특별시      강남구   세곡동        한식   국/탕/백반류    일반한식/백반  01.남성
# ...

# %% [markdown]
# ## BC 카드 - 온라인 매출액

# %%
''' - BC카드
    기준연월
    대분류_품목코드 : 11
    대분류_품목명 : 패션잡화
    중분류_품목코드 : 1112
    중분류_품목명 : 가방
    성별 : 여성
    연령대 : 40대
    라이프사이클 : 초중고자녀가구
    광역시도_코드 : 28
    광역시도_명칭 : 인천광역시
    시군구코드 : 2826
    시군구명칭 : 서구
    법정동코드 : 2826011300
    법정동명칭 : 마전동
    고객수 : 7
    매출금액 : 1304670
    매출건수 : 9
'''

# %%
bc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   기준연월      100 non-null    int64
#  1   대분류_품목코드  100 non-null    int64
#  2   대분류_품목명   100 non-null    object
#  3   중분류_품목코드  100 non-null    int64
#  4   중분류_품목명   100 non-null    object
#  5   성별        100 non-null    object
#  6   연령대       100 non-null    object
#  7   라이프사이클    100 non-null    object
#  8   광역시도_코드   100 non-null    int64
#  9   광역시도_명칭   100 non-null    object
#  10  시군구코드     100 non-null    int64
#  11  시군구명칭     100 non-null    object
#  12  법정동코드     100 non-null    int64
#  13  법정동명칭     100 non-null    object
#  14  고객수       100 non-null    int64
#  15  매출금액      100 non-null    int64
#  16  매출건수      100 non-null    int64
# dtypes: int64(9), object(8)
# memory usage: 13.4+ KB

# %%
bc.head(3)
# Out:
#      기준연월  대분류_품목코드 대분류_품목명  중분류_품목코드 중분류_품목명  성별  연령대   라이프사이클  광역시도_코드  \
# 0  201903        11    패션잡화      1112      가방  여성  40대  초중고자녀가구       28
# 1  201903        11    패션잡화      1112      가방  여성  40대  초중고자녀가구       11
# 2  201903        11    패션잡화      1112      가방  여성  40대  신혼영유아가구       11
#
#   광역시도_명칭  시군구코드 시군구명칭       법정동코드 법정동명칭  고객수     매출금액  매출건수
# 0   인천광역시   2826    서구  2826011300   마전동    7  1304670     9
# 1   서울특별시   1168   강남구  1168011800   도곡동    5  2406403     8
# 2   서울특별시   1130   강북구  1130510300   수유동    5   305227     4

# %% [markdown]
# ## 신한카드 - 광역시별 데이터 : 업종 매출

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   기준년월    100 non-null    int64
#  1   광역시도명   100 non-null    object
#  2   업종대분류   100 non-null    object
#  3   업종중분류   100 non-null    object
#  4   업종소분류   100 non-null    object
#  5   신규가맹점수  100 non-null    int64
#  6   해지가맹점수  100 non-null    int64
#  7   매출가맹점수  100 non-null    int64
#  8   카드매출금액  100 non-null    int64
#  9   카드매출건수  100 non-null    int64
#  10  점당매출금액  100 non-null    int64
#  11  건당매출금액  100 non-null    int64
# dtypes: int64(8), object(4)
# memory usage: 9.5+ KB

# %%
''' - 신한카드 : 광역시별
    기준년월
    광역시도명 : 강원
    업종대분류 : 문화레져
    업종중분류 : 동물
    업종소분류 : 동물농장
    신규가맹점수 : 5
    해지가맹점수 : 1
    매출가맹점수 : 8
    카드매출금액 : 11947000
    카드매출건수 : 417
    점당매출금액 : 1493377
    건당매출금액 : 28650
'''
# Out:
# ' - 신한카드 : 광역시별\n    기준년월\n    광역시도명 : 강원\n    업종대분류 : 문화레져\n    업종중분류 : 동물\n    업종소분류 : 동물농장\n    신규가맹점수 : 5\n    해지가맹점수 : 1\n    매출가맹점수 : 8\n    카드매출금액 : 11947000\n    카드매출건수 : 417\n    점당매출금액 : 1493377\n    건당매출금액 : 28650\n'

# %%
city.head(2)
# Out:
#      기준년월 광역시도명 업종대분류 업종중분류    업종소분류  신규가맹점수  해지가맹점수  매출가맹점수     카드매출금액  \
# 0  201902    강원  문화레져    동물     동물농장       0       0       8   11947000
# 1  201902    강원  문화레져    동물  애완동물/용품       5       1     188  251553000
#
#    카드매출건수   점당매출금액  건당매출금액
# 0     417  1493377   28650
# 1    6788  1338046   37058

# %% [markdown]
# ## 신한 - 서울시지역별 : 대출정보

# %%
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   기준년월    109 non-null    int64
#  1   법정동 이름  109 non-null    object
#  2   법정동 코드  109 non-null    int64
#  3   집계구 코드  109 non-null    object
#  4   직장인여부   109 non-null    int64
#  5   성별      109 non-null    int64
#  6   연령구분    109 non-null    int64
#  7   급여      109 non-null    float64
#  8   가맹점매출   109 non-null    float64
#  9   연금      109 non-null    float64
#  10  총지출     109 non-null    float64
#  11  총수신     109 non-null    float64
#  12  예금, 적금  109 non-null    float64
#  13  신탁      109 non-null    float64
#  14  수익증권    109 non-null    float64
#  15  신용대출    109 non-null    float64
#  16  담보대출    109 non-null    float64
#  17  주택대출    109 non-null    float64
#  18  전세대출    109 non-null    float64
# dtypes: float64(12), int64(5), object(2)
# memory usage: 16.3+ KB

# %%
''' 신한은행 - 서울시 지역 정보
    기준년월
    법정동 이름 : 가양동
    법정동 코드 : 1150010400
    집계구 코드 : 1150010400-101
    직장인여부 : 0
    성별 : 1
    연령구분 : 20
    급여 : 2,208,987
    가맹점매출 : 0.0
    연금 : 34,191
    총지출 : 2,273,590
    총수신 : 7,629,768
    예금,적금 : 3,545,905
    신탁 : 233,428
    수익증권 : 210,624
    신용대출 : 3,263,905
    담보대출 : 14,433,922
    주택대출 : 299,211
    전세대출 : 13,104,911
'''

# %%
seoul.head(2)
# Out:
#      기준년월 법정동 이름      법정동 코드          집계구 코드  직장인여부  성별  연령구분            급여  \
# 0  201903    가양동  1150010400  1150010400-101      0   1    20  0.000000e+00
# 1  201903    가양동  1150010400  1150010400-101      1   1    20  2.208987e+06
#
#           가맹점매출            연금           총지출           총수신        예금, 적금  \
# 0  15040.026773    197.185239  7.173819e+05  2.928034e+06  1.616215e+06
# 1      0.000000  34191.062305  2.273580e+06  7.629768e+06  3.545905e+06
#
#               신탁           수익증권          신용대출          담보대출           주택대출  \
# 0  134101.514616  131790.944139  2.101710e+05  1.247541e+06  148058.396527
# 1  233428.455452  210623.730218  3.263905e+06  1.443392e+07  298210.607477
#
#            전세대출
# 0  8.391462e+05
# 1  1.310491e+07

# %%
seoul.describe()
# Out:
#            기준년월        법정동 코드       직장인여부          성별        연령구분  \
# count     109.0  1.090000e+02  109.000000  109.000000  109.000000
# mean   201903.0  1.144534e+09    0.495413    0.522936   39.816514
# std         0.0  1.602900e+07    0.502288    0.501781   14.140934
# min    201903.0  1.121510e+09    0.000000    0.000000   20.000000
# 25%    201903.0  1.129013e+09    0.000000    0.000000   30.000000
# 50%    201903.0  1.150010e+09    0.000000    1.000000   40.000000
# 75%    201903.0  1.156013e+09    1.000000    1.000000   50.000000
# max    201903.0  1.174010e+09    1.000000    1.000000   60.000000
#
#                  급여          가맹점매출            연금           총지출           총수신  \
# count  1.090000e+02     109.000000  1.090000e+02  1.090000e+02  1.090000e+02
# mean   1.433423e+06  123276.133805  8.617902e+04  1.820371e+06  1.518168e+07
# std    1.535860e+06  151257.470081  2.716231e+05  1.083407e+06  1.271051e+07
# ...
